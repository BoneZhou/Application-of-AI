# %% [markdown]
# <a href="https://colab.research.google.com/github/BoneZhou/Application-of-AI/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Colab-Notebooks/segmentation.jpg"
image = cv2.imread(path)
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = YOLO("yolov8n.pt")
results = model(new_image)
cv2.imwrite("yolov8_demo_n.jpg", results[0].plot())
# Out:
# 0: 448x640 6 persons, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# True

# %%
image = cv2.imread("yolov8_demo_n.jpg")
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()

# %%
image = cv2.imread("yolov8_demo_x.jpg")
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-39-cea9e8abc9fc> in <cell line: 2>()
#       1 image = cv2.imread("yolov8_demo_x.jpg")
# ----> 2 new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       3 plt.imshow(new_image)
#       4 plt.show()
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
